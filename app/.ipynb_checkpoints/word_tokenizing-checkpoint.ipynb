# %%
# Load the model
# from tensorflow.keras.models import load_model

from tensorflow import keras
import pandas as pd
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
# Out:
# C:\Users\emmax\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\emmax\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\emmax\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
politics_tweet_df = pd.read_csv('../data/politics_tweet.csv')
politics_tweet_df= politics_tweet_df.drop(['Unnamed: 0'], axis=1)
politics_tweet_df.head(3)
# Out:
#          date        name                                              tweet
# 0  2020-11-15  <JoeBiden>   congratulations to nasa and spacex on today's...
# 1  2020-11-14  <JoeBiden>   to the millions of hindus, jains, sikhs, and ...
# 2  2020-11-13  <JoeBiden>   i am the president-elect, but will not be pre...

# %%
biden_tweet_df =politics_tweet_df[politics_tweet_df['name']== '<JoeBiden>']

# %%
num_words = 10000
tokenizer_biden = Tokenizer(num_words=num_words)
tokenizer_biden.fit_on_texts(biden_tweet_df["tweet"].tolist())

# %%
tokenizer_biden.word_index
# Out:
# {'the': 1,
#  'to': 2,
#  'and': 3,
#  'of': 4,
#  'a': 5,
#  'we': 6,
#  'in': 7,
#  'this': 8,
#  'our': 9,
#  'is': 10,
#  'i': 11,
#  'for': 12,
#  '—': 13,
#  'president': 14,
#  'it': 15,
#  'trump': 16,
#  'you': 17,
#  'on': 18,
#  'that': 19,
#  'have': 20,
#  'donald': 21,
#  'are': 22,
#  'will': 23,
#  'be': 24,
#  'as': 25,
#  'with': 26,
#  'your': 27,
#  'not': 28,
#  'need': 29,
#  'but': 30,
#  'who': 31,
#  'all': 32,
#  'do': 33,
#  'can': 34,
#  'he': 35,
#  'us': 36,
#  'one': 37,
#  'nation': 38,
#  'from': 39,
#  'american': 40,
#  'people': 41,
#  'has': 42,
#  'if': 43,
#  'my': 44,
#  'day': 45,
#  'more': 46,
#  'country': 47,
#  'every': 48,
#  'at': 49,
#  'get': 50,
#  'his': 51,
#  'today': 52,
#  'just': 53,
#  'together': 54,
#  'make': 55,
#  'vote': 56,
#  'their': 57,
#  'up': 58,
#  'out': 59,
#  'time': 60,
#  'america': 61,
#  'now': 62,
#  'about': 63,
#  'it’s': 64,
#  "it's": 65,
#  'no': 66,
#  'what': 67,
#  'crisis': 68,
# ...

# %%
word_index_dict = {
 'president': 14,
 
 'trump': 16,

 'donald': 21,
 
 'nation': 38,
 
 'american': 40,
 'people': 41,
 'country': 47,

 'today': 52,



 'vote': 56,
 

 'time': 60,
 'america': 61,
 'now': 62,
 'what': 67,
 'crisis': 68,
 'americans': 69,
 'health': 70,
 'when': 71,
 
 'care': 73,
 'help': 74,
 'covid': 78,
 'back': 81,
 '19': 82,
 'folks': 83,
 'going': 84,
 'campaign': 87,
 'work': 89,
 'years': 90,
 'better': 94,

 'tune': 96,

 'white': 98,

 'election': 100,


 'build': 104,
 'house': 105,
 'chip': 108,
 'everyone': 109,
 'future': 110,

 'right': 112,
 'fight': 114,

 'across': 116,
 'head': 117,


 'administration': 120,
 'workers': 121,
 'ensure': 123,
 'world': 124,
 'days': 132,

 'promise': 134,

 'moment': 136,
 'come': 137,
 'economy': 139,
 'change': 142,
 'pandemic': 143,
 'protect': 145,
 'support': 148,
 'violence': 150,
 'plan': 151,

 'climate': 154,

 'join': 156,
 'hard': 157,
 'soul': 159,
 'life': 160,
 'leadership': 161,
 'made': 162,
 'first': 163,
 'win': 165,
 'job': 166,
 'safe': 167,
 'keep': 168,
 'stand': 169,
 'truth': 170,
 'big': 171,
 'power': 172,
 'families': 174,
 'middle': 176,
 'action': 177,
 'act': 178,
 'million': 179,
 'hope': 181,
 'ballot': 182,
 'public': 183,
 'virus': 184,
 'believe': 190,
 'deserve': 191,
 'history': 192,
 'live': 193,
 'states': 195,
 'family': 198,
 'millions': 199,
 'beat': 200,
 'jobs': 202,
 'justice': 203,
 'economic': 204,
 'failed': 205,
 'everything': 206,
 'lead': 208,
 'few': 209,
 'many': 210,
 'were': 211,
 'would': 212,
 'single': 213,
 'against': 214,
 'working': 215,
 'person': 216,
 'november': 217,
 'united': 218,
 'long': 220,
 'said': 221,
 'gun': 222,
 'sure': 224,
 'best': 225,
 'much': 226,
 'done': 227,
 '000': 228,
 'watch': 229,
 'proud': 230,


 'thing': 233,
 'battle': 234,
 'jill': 235,

 'another': 241,
 'tonight': 242,
 'good': 243,
 'trump’s': 244,
 'community': 245,
 'bring': 247,
 'around': 249,

 'honor': 251,
 'biden': 252,

 'after': 254,


 'coronavirus': 258,
 'voting': 259,

 'enough': 261,
 'doing': 262,
 "trump's": 263,
 'choose': 264,
 'paying': 265,

 'demdebate': 267,
 'year': 268,
 'being': 269,
 'heard': 270,
 'night': 271,
 'without': 272,
 'next': 273,
 'full': 274,
 'we’ve': 275,
 'running': 276,
 'important': 277,
 "we'll": 278,
 "that's": 279,
 'may': 280,
 'response': 281,
 'great': 282,
 '”': 283,
 'things': 284,
 'deal': 285,
 'mr': 286,
 'ago': 287,
 'left': 288,
 'de': 289,
 'comes': 290,
 'elected': 291,
 'testing': 292,
 'threat': 293,
 'stronger': 294,
 'there’s': 295,
 'real': 296,
 'that’s': 297,
 'stop': 298,
 'hate': 299,
 'stake': 300,
 'needs': 301,
 'nothing': 302,
 "you're": 303,
 'voice': 304,
 'here': 305,
 'look': 306,
 'he’s': 307,
 'class': 308,
 'making': 309,
 'during': 310,
 'place': 311,
 'forward': 312,
 'ahead': 313,
 'chance': 314,
 "i've": 315,
 'step': 316,
 'access': 317,
 'restore': 318,
 'worst': 319,
 'women': 320,
 'fair': 321,
 'please': 322,
 'grateful': 323,
 'national': 324,
 'science': 325,
 'ready': 326,
 'line': 327,
 'once': 328,
 'won’t': 329,
 'lost': 330,
 'home': 331,
 'then': 332,
 'pm': 333,
 'obamacare': 334,
 'months': 335,
 'u': 336,
 'its': 337,
 'experts': 338,
 'listen': 339,
 's': 340,
 'demconvention': 341,
 'face': 342,
 'democracy': 343,
 'fear': 344,
 'overcome': 345,
 'create': 346,
 'wealthy': 347,
 'communities': 348,
 'front': 349,
 'path': 350,
 'tell': 351,
 'state': 352,
 'even': 353,
 'defeat': 354,
 'global': 355,
 'yet': 356,
 'happen': 357,
 'off': 358,
 'some': 359,
 'trying': 360,
 'am': 361,
 'continue': 362,

 'small': 365,
 'well': 366,
 'final': 367,
 'free': 368,
 'et': 369,
 'dignity': 370,
 'carolina': 371,
 'unite': 372,
 'price': 373,
 'does': 374,
 'prayers': 375,
 'affordable': 376,
 'court': 377,
 'faith': 378,
 'stay': 379,
 'use': 380,
 'two': 381,
 'week': 382,
 'black': 383,
 'town': 384,
 'law': 385,
 'while': 386,
 'needed': 387,
 'discuss': 388,
 "won't": 389,
 'each': 390,
 'love': 391,
 'own': 392,
 'able': 393,
 'obama': 394,
 'character': 395,
 'equal': 396,
 'possible': 397,
 'stage': 398,
 'relief': 399,
 'office': 400,
 'call': 401,
 'matter': 402,
 'same': 403,
 'powerful': 404,
 'division': 405,
 'tomorrow': 406,
 'senate': 407,
 'opportunity': 408,
 'wait': 409,
 "here's": 410,
 'equality': 411,
 'pass': 412,
 'security': 413,
 'hall': 414,
 'south': 415,
 'friends': 416,
 'here’s': 417,
 'think': 418,
 'instead': 419,
 "there's": 420,
 'iowa': 421,
 'makes': 422,
 'values': 423,
 'tough': 424,
 'friend': 425,
 'month': 426,
 'social': 427,
 'meet': 428,
 'lot': 429,
 'lines': 430,
 'war': 431,
 'businesses': 432,
 'mask': 433,
 'doesn’t': 434,
 'race': 435,
 'la': 436,
 'getting': 437,
 'entire': 438,
 'finally': 439,
 'register': 440,
 'we’ll': 441}

# %%
len(word_index_dict.keys())
# Out:
# 307

# %%
word_index_list = word_index_dict.keys()

# %%
wordcloud_list = []
for word in word_index_list:
    temp_dict = {'text': (word), 'value': (tokenizer_biden.word_counts[word])}
    wordcloud_list.append(temp_dict)

wordcloud_list
# Out:
# [{'text': 'president', 'value': 778},
#  {'text': 'trump', 'value': 762},
#  {'text': 'donald', 'value': 611},
#  {'text': 'nation', 'value': 339},
#  {'text': 'american', 'value': 327},
#  {'text': 'people', 'value': 324},
#  {'text': 'country', 'value': 301},
#  {'text': 'today', 'value': 274},
#  {'text': 'vote', 'value': 262},
#  {'text': 'time', 'value': 246},
#  {'text': 'america', 'value': 243},
#  {'text': 'now', 'value': 242},
#  {'text': 'what', 'value': 230},
#  {'text': 'crisis', 'value': 223},
#  {'text': 'americans', 'value': 214},
#  {'text': 'health', 'value': 214},
#  {'text': 'when', 'value': 213},
#  {'text': 'care', 'value': 212},
#  {'text': 'help', 'value': 211},
#  {'text': 'covid', 'value': 197},
#  {'text': 'back', 'value': 182},
#  {'text': '19', 'value': 181},
#  {'text': 'folks', 'value': 181},
#  {'text': 'going', 'value': 179},
#  {'text': 'campaign', 'value': 168},
#  {'text': 'work', 'value': 167},
#  {'text': 'years', 'value': 164},
# ...

# %%
trump_tweet_df =politics_tweet_df[politics_tweet_df['name']== '<realDonaldTrump>']
num_words = 10000
tokenizer_trump = Tokenizer(num_words=num_words)
tokenizer_trump.fit_on_texts(trump_tweet_df["tweet"].tolist())
tokenizer_trump.word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'to': 3,
#  'of': 4,
#  'a': 5,
#  'in': 6,
#  'is': 7,
#  'for': 8,
#  'will': 9,
#  'i': 10,
#  'our': 11,
#  'on': 12,
#  'be': 13,
#  'are': 14,
#  'great': 15,
#  'you': 16,
#  'that': 17,
#  'we': 18,
#  'amp': 19,
#  'it': 20,
#  'they': 21,
#  'he': 22,
#  'with': 23,
#  'have': 24,
#  'this': 25,
#  'has': 26,
#  'was': 27,
#  'my': 28,
#  'all': 29,
#  'people': 30,
#  'by': 31,
#  'your': 32,
#  'not': 33,
#  'biden': 34,
#  'at': 35,
#  'thank': 36,
#  'very': 37,
#  'just': 38,
#  'news': 39,
#  'as': 40,
#  'now': 41,
#  'joe': 42,
#  'big': 43,
#  'so': 44,
#  'from': 45,
#  'vote': 46,
#  'who': 47,
#  'fake': 48,
#  'up': 49,
#  'do': 50,
#  'but': 51,
#  'more': 52,
#  'out': 53,
#  'his': 54,
#  'no': 55,
#  'than': 56,
#  'get': 57,
#  'their': 58,
#  'new': 59,
#  'would': 60,
#  'never': 61,
#  'president': 62,
#  'country': 63,
#  'total': 64,
#  'or': 65,
#  '”': 66,
#  'if': 67,
#  'complete': 68,
#  'democrats': 69,
# ...

# %%
trump_dict = {
 'great': 15,
 
 'amp': 19,

 'people': 30,

 'biden': 34,

 'thank': 36,

 'news': 39,
 
 'joe': 42,
 'big': 43,
 
 'vote': 46,
 
 'fake': 48,
 
 'more': 52,

 'their': 58,
 'new': 59,
 'never': 61,
 'president': 62,
 'country': 63,
 'total': 64,
 


 'complete': 68,
 'democrats': 69,
 'endorsement': 70,
 'trump': 71,
 'what': 72,
 
 'many': 74,


 'state': 77,

 'like': 79,
 'job': 80,

 'american': 82,
 'america': 83,

 'going': 85,
 'election': 86,
 'states': 87,
 'win': 88,


 'years': 91,



 'make': 95,

 'which': 97,
 'military': 98,
 'amendment': 99,


 'maga': 102,
 'china': 103,

 'other': 105,

 'strong': 107,

 'second': 109,
 'good': 110,
 'today': 111,
 'one': 112,
 'time': 113,


 'nothing': 116,
 'over': 117,
 'media': 118,

 'see': 120,
 'down': 121,
 'democrat': 122,
 'radical': 123,


 'history': 126,
 'sleepy': 127,
 'jobs': 128,
 'had': 129,

 'house': 131,




 'us': 136,

 'far': 138,
 'law': 139,
 'republican': 140,
 'federal': 141,
 'bad': 142,
 'always': 143,
 'vets': 144,

 'pennsylvania': 146,



 'crime': 150,

 'world': 152,
 'first': 153,
 'before': 154,

 'against': 156,

 'party': 158,


 'made': 162,
 'congressman': 163,
 'corrupt': 164,
 'said': 165,
 'national': 166,
 'after': 167,
 'united': 168,
 'being': 169,
 'order': 170,
 'hard': 171,
 'well': 172,

 'working': 174,
 'incredible': 175,

 'white': 177,

 'really': 179,
 'day': 180,
 'mike': 181,

 'court': 183,
 'usa': 184,
 'soon': 185,
 'dems': 186,
 'ballots': 187,
 'coronavirus': 188,
 'night': 189,
 'know': 190,

 'work': 192,
 'hoax': 193,
 'york': 194,
 'economy': 195,
 'border': 196,
 'better': 199,
 'others': 200,
 'government': 201,
 'support': 202,
 'washington': 203,
 'police': 205,
 'taxes': 206,
 'congress': 207,
 'numbers': 208,
 'crazy': 209,
 'keep': 211,
 'money': 212,
 'political': 213,

 'look': 215,
 'governor': 216,
 'russia': 217,
 'right': 218,
 'another': 219,
 'totally': 223,
 'bernie': 224,
 'michigan': 225,
 'campaign': 226,
 'things': 227,
 'republicans': 228,
 'protect': 229,
 'watch': 230,
 'coming': 231,
 'life': 232,
 'important': 234,
 'impeachment': 235,

 'obama': 237,

 'together': 239,


 'congratulations': 242,
 'getting': 243,
 'carolina': 244,
 'open': 245,
 'testing': 246,
 'mail': 247,
 'say': 248,
 'florida': 249,
 'tremendous': 250,
 'november': 252,
 'record': 253,
 'where': 254,
 'polls': 255,
 'wisconsin': 256,
 'enforcement': 257,
 'fast': 258,
 'mini': 259,
 'john': 260,
 'texas': 261,
 'tonight': 262,
 'love': 263,
 'north': 265,
 'take': 266,
 'administration': 267,
 'voting': 268,
 'wonderful': 269,
 'come': 270,
 'called': 271,
 'senate': 272,
 'everything': 273,
 'everyone': 275,
 '2016': 276,
 'wants': 277,
 'small': 278,
 'high': 279,
 'virus': 280,
 'happen': 281,
 'year': 282,
 'book': 284,
 'those': 285,
 'security': 286,
 'place': 287,
 'early': 288,
 'supreme': 289,
 'energy': 290,
 'senator': 291,
 'lamestream': 292,
 'fight': 293,
 'nancy': 294,
 'pelosi': 295,
 'conference': 296,
 'including': 297,
 'million': 298,
 'americans': 299,
 'wrong': 302,
 'countries': 303,
 'loves': 304,
 'remember': 307,
 'under': 308,
 'honor': 309,
 'family': 310,
 'cases': 311,
 'real': 312,
 'approval': 313,
 'deal': 315,
 'trying': 316,
 'having': 317,
 'poll': 319,
 'number': 320,
 'end': 321,
 'cities': 322,
 'running': 323,
 'dollars': 324,
 '5': 325,
 'safe': 326,
 'covid': 327,
 'wall': 329,
 'badly': 330,
 'stand': 331,
 'ready': 332,
 'happy': 333,
 'act': 334,
 'low': 335,
 'strongly': 336,
 'tax': 337,
 'lives': 338,
 'biggest': 339,
 'fact': 340,
 '4': 341,
 'while': 342,
 '3rd': 343,
 'stop': 344,
 'workers': 345,
 'borders': 346,
 'anarchists': 347,
 'supports': 348,
 'wins': 349,
 'rating': 350,
 'taking': 351,
 'story': 354,
 'until': 355,
 'farmers': 357,
 'iran': 358,
 'won’t': 359,
 'ratings': 360,
 'city': 361,
 '“the': 362,
 'ballot': 363,
 'looking': 364,
 'days': 365,
 'iowa': 366,
 'through': 367,
 'guard': 368,
 'disaster': 369,
 'votes': 370,
 'mayor': 371,
 'millions': 372
             }

# %%
trump_dict_key = trump_dict.keys()
trump_dict_list = []
for word in word_index_list:
    temp_dict = {'text': (word), 'value': (tokenizer_biden.word_counts[word])}
    wordcloud_list.append(temp_dict)

wordcloud_list
